# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date

# %% [markdown]
# # 1

# %%
df = pd.read_csv('anime.csv')
df.shape
# Out:
# (17562, 35)

# %%
df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name   Type Episodes  \
# 0                         カウボーイビバップ     TV       26
# 1                    カウボーイビバップ 天国の扉  Movie        1
# 2                             トライガン     TV       26
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)     TV       26
# 4                            冒険王ビィト     TV       52
#
#                           Aired    Premiered  ...  Score-10   Score-9  \
# 0   Apr 3, 1998 to Apr 24, 1999  Spring 1998  ...  229170.0  182126.0
# 1                   Sep 1, 2001      Unknown  ...   30043.0   49201.0
# 2   Apr 1, 1998 to Sep 30, 1998  Spring 1998  ...   50229.0   75651.0
# 3   Jul 2, 2002 to Dec 24, 2002  Summer 2002  ...    2182.0    4806.0
# 4  Sep 30, 2004 to Sep 29, 2005    Fall 2004  ...     312.0     529.0
#
#     Score-8  Score-7  Score-6 Score-5 Score-4  Score-3  Score-2  Score-1
# 0  131625.0  62330.0  20688.0  8904.0  3184.0   1357.0    741.0   1580.0
# 1   49505.0  22632.0   5805.0  1877.0   577.0    221.0    109.0    379.0
# 2   86142.0  49432.0  15376.0  5838.0  1965.0    664.0    316.0    533.0
# 3   10128.0  11618.0   5709.0  2920.0  1083.0    353.0    164.0    131.0
# 4    1242.0   1713.0   1068.0   634.0   265.0     83.0     50.0     27.0
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17562 entries, 0 to 17561
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MAL_ID         17562 non-null  int64
#  1   Name           17562 non-null  object
#  2   Score          17562 non-null  object
#  3   Genres         17562 non-null  object
#  4   English name   17562 non-null  object
#  5   Japanese name  17562 non-null  object
#  6   Type           17562 non-null  object
#  7   Episodes       17562 non-null  object
#  8   Aired          17562 non-null  object
#  9   Premiered      17562 non-null  object
#  10  Producers      17562 non-null  object
#  11  Licensors      17562 non-null  object
#  12  Studios        17562 non-null  object
#  13  Source         17562 non-null  object
#  14  Duration       17562 non-null  object
#  15  Rating         17562 non-null  object
#  16  Ranked         17562 non-null  object
#  17  Popularity     17562 non-null  int64
#  18  Members        17562 non-null  int64
#  19  Favorites      17562 non-null  int64
#  20  Watching       17562 non-null  int64
#  21  Completed      17562 non-null  int64
#  22  On-Hold        17562 non-null  int64
#  23  Dropped        17562 non-null  int64
#  24  Plan to Watch  17562 non-null  int64
#  25  Score-10       17562 non-null  object
#  26  Score-9        17562 non-null  object
#  27  Score-8        17562 non-null  object
#  28  Score-7        17562 non-null  object
#  29  Score-6        17562 non-null  object
#  30  Score-5        17562 non-null  object
#  31  Score-4        17562 non-null  object
#  32  Score-3        17562 non-null  object
#  33  Score-2        17562 non-null  object
#  34  Score-1        17562 non-null  object
# dtypes: int64(9), object(26)
# memory usage: 4.7+ MB

# %%
df = df.drop(['English name','Japanese name','Aired','Licensors','Completed','On-Hold','Dropped','Plan to Watch','Score-10','Score-9','Score-8','Score-7','Score-6','Score-5','Score-4','Score-3','Score-2','Score-1'],axis= 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17562 entries, 0 to 17561
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MAL_ID      17562 non-null  int64
#  1   Name        17562 non-null  object
#  2   Score       17562 non-null  object
#  3   Genres      17562 non-null  object
#  4   Type        17562 non-null  object
#  5   Episodes    17562 non-null  object
#  6   Premiered   17562 non-null  object
#  7   Producers   17562 non-null  object
#  8   Studios     17562 non-null  object
#  9   Source      17562 non-null  object
#  10  Duration    17562 non-null  object
#  11  Rating      17562 non-null  object
#  12  Ranked      17562 non-null  object
#  13  Popularity  17562 non-null  int64
#  14  Members     17562 non-null  int64
#  15  Favorites   17562 non-null  int64
#  16  Watching    17562 non-null  int64
# dtypes: int64(5), object(12)
# memory usage: 2.3+ MB

# %%
null_columns = df.columns[df.isnull().any()] 
df[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# # 2

# %% [markdown]
# •	Analysis with one categorical variable

# %%
df['Type'].unique()
# Out:
# array(['TV', 'Movie', 'OVA', 'Special', 'ONA', 'Music', 'Unknown'],
#       dtype=object)

# %%
group_by_type = df.groupby('Type')[['MAL_ID']].agg('count').rename(columns = {'MAL_ID' : 'count'})
group_by_type = group_by_type.reset_index()
group_by_type
# Out:
#       Type  count
# 0    Movie   3041
# 1    Music   1469
# 2      ONA   1907
# 3      OVA   3894
# 4  Special   2218
# 5       TV   4996
# 6  Unknown     37

# %%
fig, ax = plt.subplots(figsize = (14, 10))
explode = [0, 0, 0, 0, 0, 0.2, 0]
ax.pie(group_by_type['count'], autopct="%.1f%%",explode = explode,shadow = True, labels = group_by_type['Type'])
ax.set_ylabel('Number of Animes for each type')
#rotate the label's text
plt.show()

# %% [markdown]
# •	Analysis with one numerical variable

# %%
members = df.sort_values(by = 'Members', ascending = False).iloc[:50]
members = members.sort_index()
members
# Out:
#        MAL_ID                                    Name Score  \
# 0           1                            Cowboy Bebop  8.78
# 10         20                                  Naruto  7.91
# 11         21                               One Piece  8.52
# 176       199           Sen to Chihiro no Kamikakushi  8.83
# 202       226                              Elfen Lied  7.56
# 245       269                                  Bleach   7.8
# 1393     1535                              Death Note  8.63
# 1431     1575         Code Geass: Hangyaku no Lelouch  8.72
# 1574     1735                      Naruto: Shippuuden  8.16
# 1822     2001              Tengen Toppa Gurren Lagann  8.66
#
#        Watching
# 0        105808
# 10       137167
# 11       887333
# 176       14444
# 202       36600
# 245      207985
# 1393     122401
# 1431      69924
# 1574     362124
# 1822      70769
# 2656      38149
# 3155      87632
# 3564      72442
# 3971     171871
# 4636      55803
# 4707     185463
# 5683     114349
# 5975      60451
# 6295      66219
# 6474     227277
# 6489      40503
# 6614      80304
# 7013      81722
# 7449     140753
# 7939      88881
# 8148      66938
# 8292      64183
# 8305      83029
# 8551      65821
# 8625      65450
# 8646      74612
# 8704      67042
# 8883      78753
# 9011      61527
# 9211      80929
# 9383      72638
# 9664      41115
# 9742      60991
# 9886      30379
# 10451     96568
# 10677     59954
# 10795     52888
# 10876    106570
# 11185     90902
# 11260     68041
# 11308     40773
# 11914    110626
# 13252     62604
# 13644    123477
# 14631    154413

# %%
# Out:
#    MAL_ID          Name Score  \
# 0       1  Cowboy Bebop  8.78
#
#                                             Genres Type Episodes    Premiered  \
# 0  Action, Adventure, Comedy, Drama, Sci-Fi, Space   TV       26  Spring 1998
#
#        Producers  Studios    Source         Duration  \
# 0  Bandai Visual  Sunrise  Original  24 min. per ep.
#
#                            Rating Ranked  Popularity  Members  Favorites  \
# 0  R - 17+ (violence & profanity)   28.0          39  1251960      61971
#
#    Watching
# 0    105808

# %%
fig, ax = plt.subplots(figsize = (12, 8))
sns.scatterplot(data=members, x="Name", y="Members")
ax.set_xlabel('Name of Anime')
ax.set_ylabel('Number of Members for each Anime')
ax.set_xticklabels(members["Name"], rotation = 90)
plt.show()
# Out:
# <ipython-input-44-dc44d0625ad3>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(members["Name"], rotation = 90)

# %% [markdown]
# •	Analysis with date/datetime values

# %%
date_count = df.Premiered.str.extract('(\d+)').rename(columns = {0 : 'Year'})
date_count['Year'] = pd.to_datetime(date_count['Year'])
date_count = date_count.groupby('Year')[['Year']].agg('count').rename(columns = {'Year' : 'count'})
date_count = date_count.reset_index()

# %%
fig, ax = plt.subplots(figsize = (12,8))
ax.plot(date_count['Year'], date_count['count'], linestyle='-', color = 'r')
ax.set_xlabel('Year')
ax.set_ylabel('Count of Animes in each year')
ax.set_title('The year of the most popular animes')
ax.grid(True)
plt.show()

# %% [markdown]
# •	Analysis with set of two variables

# %%
group_type_rating = df.groupby(['Type','Rating'])[['MAL_ID']].agg('count').rename(columns = {'MAL_ID' : 'count'})
group_type_rating = group_type_rating.reset_index()

# %%
fig, ax = plt.subplots(figsize = (14, 8))
sns.barplot(ax = ax, data = group_type_rating, x = 'Type', y = 'count', hue = 'Rating')
ax.set_xlabel('Type')
ax.set_ylabel('Count of Animes')
ax.set_title('Number of Animes by Type of each Rating')
# Out:
# Text(0.5, 1.0, 'Number of Animes by Type of each Rating')

# %% [markdown]
# •	Groupby and apply filtration on the data

# %%
total_count = df.groupby('Studios').filter(lambda x: x['MAL_ID'].count() > 100)
row_indexes = total_count[total_count['Studios'] == 'Unknown'].index
total_count.drop(row_indexes, inplace = True)
unique_studios = total_count['Studios'].unique()
print('Name of studios that have over 100 anime: ')
for i in unique_studios:
    print(i)
# Out:
# Name of studios that have over 100 anime:
# Sunrise
# Bones
# Madhouse
# Toei Animation
# J.C.Staff
# Nippon Animation
# Studio Pierrot
# Gonzo
# Studio Deen
# OLM
# Production I.G
# AIC
# Xebec
# Kyoto Animation
# TMS Entertainment
# Shin-Ei Animation
# Tatsunoko Production
# Shaft
# A-1 Pictures
# DLE

# %%
total_count['Studios'].value_counts()
# Out:
# Toei Animation          755
# Sunrise                 479
# J.C.Staff               358
# Madhouse                324
# TMS Entertainment       277
# Production I.G          266
# Studio Deen             263
# Studio Pierrot          249
# OLM                     212
# Nippon Animation        208
# A-1 Pictures            193
# DLE                     167
# Shin-Ei Animation       166
# Tatsunoko Production    141
# Bones                   127
# AIC                     122
# Gonzo                   121
# Shaft                   119
# Kyoto Animation         115
# Xebec                   114
# Name: Studios, dtype: int64

# %% [markdown]
# •	My own features

# %%
group_by_studios = df.groupby('Studios')[['MAL_ID']].agg('count').rename(columns = {'MAL_ID' : 'count'})
group_by_studios = group_by_studios.sort_values(by='count',ascending = False).iloc[:21]
group_by_studios = group_by_studios.drop('Unknown')
group_by_studios
# Out:
#                       count
# Studios
# Toei Animation          755
# Sunrise                 479
# J.C.Staff               358
# Madhouse                324
# TMS Entertainment       277
# Production I.G          266
# Studio Deen             263
# Studio Pierrot          249
# OLM                     212
# Nippon Animation        208
# A-1 Pictures            193
# DLE                     167
# Shin-Ei Animation       166
# Tatsunoko Production    141
# Bones                   127
# AIC                     122
# Gonzo                   121
# Shaft                   119
# Kyoto Animation         115
# Xebec                   114

# %%
fig, ax = plt.subplots(figsize = (12, 8))
ax.bar(group_by_studios.index, group_by_studios['count'])
ax.set_ylabel('Number of Animes for each studio')
ax.set_xticklabels(group_by_studios.index,rotation = 90)
plt.show()
# Out:
# <ipython-input-24-2c7cf487aa7c>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(group_by_studios.index,rotation = 90)

# %%
name_popularity = df[['Name','Watching']].sort_values(by='Watching', ascending = False).iloc[:15]
name_popularity
# Out:
#                                                     Name  Watching
# 11                                             One Piece    887333
# 15926               Shingeki no Kyojin: The Final Season    566239
# 16342                                Jujutsu Kaisen (TV)    533016
# 12493                                       Black Clover    530324
# 1574                                  Naruto: Shippuuden    362124
# 12492                    Boruto: Naruto Next Generations    282596
# 15710                   Yakusoku no Neverland 2nd Season    260775
# 17165                                           Horimiya    245814
# 16401                              Dr. Stone: Stone Wars    229258
# 6474                              Hunter x Hunter (2011)    227277
# 16878  Re:Zero kara Hajimeru Isekai Seikatsu 2nd Seas...    214713
# 15663           Mushoku Tensei: Isekai Ittara Honki Dasu    213381
# 245                                               Bleach    207985
# 4707                                          Fairy Tail    185463
# 15674          Tensei shitara Slime Datta Ken 2nd Season    173043

# %%
fig, ax = plt.subplots(figsize = (12, 8))
ax.barh(name_popularity['Name'], name_popularity['Watching'])
ax.set_xlabel('Number of users who are watching the anime')
plt.show()
